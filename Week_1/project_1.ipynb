# %%
p = float(input("Enter principal: "))
r = float(input("Enter rate: "))
t = float(input("Enter time: "))

si = (p * r * t) / 100

print("The Simple Interest is:", si)
# Out:
# Enter principal:  7
# Enter rate:  4
# Enter time:  2
# The Simple Interest is: 0.56
