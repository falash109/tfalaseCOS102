# %%
print("Class Student Data")
print()

girl_names = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
girl_ages = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
girl_heights = [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
girl_scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

boy_names = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
boy_ages = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
boy_heights = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
boy_scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

print("GIRLS")
print("Name\t\tAge\tHeight\tScore")
print("-" * 40)

for i in range(10):
    print(girl_names[i], "\t\t", girl_ages[i], "\t", girl_heights[i], "\t", girl_scores[i])

print()
print("BOYS")
print("Name\t\tAge\tHeight\tScore")
print("-" * 40)

for i in range(10):
    print(boy_names[i], "\t\t", boy_ages[i], "\t", boy_heights[i], "\t", boy_scores[i])

print()
print("Total Students: 20 (10 girls, 10 boys)")

average_girl_score = sum(girl_scores) / 10
average_boy_score = sum(boy_scores) / 10

print("Average score for girls:", average_girl_score)
print("Average score for boys:", average_boy_score)
# Out:
# Class Student Data
#
# GIRLS
# Name		Age	Height	Score
# ----------------------------------------
# Evelyn 		 17 	 5.5 	 80
# Jessica 		 16 	 6.0 	 85
# Somto 		 17 	 5.4 	 70
# Edith 		 18 	 5.9 	 60
# Liza 		 16 	 5.6 	 76
# Madonna 		 18 	 5.5 	 66
# Waje 		 17 	 6.1 	 87
# Tola 		 20 	 6.0 	 95
# Aisha 		 19 	 5.7 	 50
# Latifa 		 17 	 5.5 	 49
#
# BOYS
# Name		Age	Height	Score
# ----------------------------------------
# Chinedu 		 19 	 5.7 	 74
# Liam 		 16 	 5.9 	 87
# Wale 		 18 	 5.8 	 75
# Gbenga 		 17 	 6.1 	 68
# Abiola 		 20 	 5.9 	 66
# Kola 		 19 	 5.5 	 78
# Kunle 		 16 	 6.1 	 87
# George 		 18 	 5.4 	 98
# Thomas 		 17 	 5.8 	 54
# Wesley 		 19 	 5.7 	 60
#
# Total Students: 20 (10 girls, 10 boys)
# Average score for girls: 71.8
# Average score for boys: 74.7
