# %%
print("Izifin Technology - Annual Tax Revenue Calculator")
print()

years = float(input("Enter years of experience: "))
age = float(input("Enter age of staff: "))

if years > 25 and age >= 55:
    atr = 5600000
    print("Annual Tax Revenue: N5,600,000")
elif years > 20 and age >= 45:
    atr = 4480000
    print("Annual Tax Revenue: N4,480,000")
elif years > 10 and age >= 35:
    atr = 1500000
    print("Annual Tax Revenue: N1,500,000")
else:
    atr = 550000
    print("Annual Tax Revenue: N550,000")

print("Thank you for using Izifin Tax Calculator")
# Out:
# Izifin Technology - Annual Tax Revenue Calculator
# Enter years of experience:  7
# Enter age of staff:  25
# Annual Tax Revenue: N550,000
# Thank you for using Izifin Tax Calculator
